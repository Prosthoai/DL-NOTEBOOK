# %% [markdown]
# #**Deep Learning (DL)**
#
# **Supervised Learning**: *occurs when DL model learns and makes inferences from labeled data*
#
# **Unsupervised Learning**:*occurs when DL model learns and makes inferencese from unlabeled data*
#
# **labeled vs. unlabeled** labeled-> classify cats&dogs in the image. unlabeled->recognize feature in the image without classfying.

# %% [markdown]
# #**Artificial Neural Networks (ANNs)***

# %% [markdown]
# #***Keras Sequential Model***
#
# *The sequential model is a linear stack of layers*

# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation 
model=Sequential([
                  Dense(32, input_shape=(10,),activation='relu'),
                  Dense(2, activation='softmax'),
])

# %% [markdown]
# Dense is a most basic type of layer in the neural network and it connects each input and each output within the layer.

# %% [markdown]
# #***Layers in an ANN***
#
# ANN are typically organized in layers. Different types of layers includes:
#
#
# *   Dense (or fully connected) Layers
# *   Convolutional Layers
# *   Pooling Layers
# *   Recurrent Layers
# *   Normalization Layers
# *   Etc.

# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation 
model=Sequential([
                  Dense(5, input_shape=(3,),activation='relu'),
                  Dense(2, activation='softmax'),
])

# %% [markdown]
# Dense(5,) is the first hidden layer, not the input layer.
#
#     The input _shape is the num of inputs.
#
#     Only the first dense of the sequential model requires a input_shape.

# %%
# !pip install scipy==1.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 31.2 MB 300 kB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# jax 0.3.8 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
from tensorflow.python.util.tf_export import InvalidSymbolNameError
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
# %matplotlib inline

img=np.expand_dims(ndimage.imread('NN.PNG'),0)
plt.imshow(img[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   import sys
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-cf65473a6339> in <module>()
#       5 get_ipython().magic('matplotlib inline')
#       6
# ----> 7 img=np.expand_dims(ndimage.imread('NN.PNG'),0)
#       8 plt.imshow(img[0])
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      95             """`arrayrange` is deprecated, use `arange` instead!"""
#      96             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# ---> 97             return func(*args, **kwds)
#      98
#      99         newfunc = _set_function_name(newfunc, old_name)
#
# ...

# %% [markdown]
# #***Activation function***
# The activation function defines tthe output of that neuron given a set of inputs

# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation 

model=Sequential ([
                   Dense(5,input_shape=(3,),activation='relu')
])

# %%
model=Sequential()
model.add(Dense(5,input_shape=(3,)))
model.add(Activation('relu'))

# %% [markdown]
# # ***Training***
#
# Solving an optimization problem
#
#
# *   optimizing weights(with SGD)
# *   Objective: Minimize the loss function

# %% [markdown]
# # ***Learning***

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement keras.optimizers (from versions: none)
# ERROR: No matching distribution found for keras.optimizers

# %%
import keras
import tensorflow.keras
from keras import backend as k
from keras.models import Sequential
from keras.layers import Activation 
from keras.layers.core import Dense
from tensorflow.keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
model=Sequential([
                  Dense(16,input_shape=(1,),activation="relu"),
                  Dense(32,activation="relu"),
                  Dense(2, activation="softmax")
])

# %%
model.compile(Adam(lr=.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# optimizer: SGD, Adam(variation SGD), etc.
#
# loss function:

# %%
model.fit(scaled_trained_samples, train_labels, batch_size=10, epochs=20, shuffle=True, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f1ada5507a7f> in <module>()
# ----> 1 model.fit(scaled_trained_samples, train_labels, batch_size=10, epochs=20, shuffle=True, verbose=2)
#
# NameError: name 'scaled_trained_samples' is not defined

# %% [markdown]
# numpy array: 'scaled_trained_samples
#
# batch_size: how many data being trained at once
#
# epoch: from input to output= 1 epoch
#
# verbose: num of outputs

# %% [markdown]
# #**Lossfunction (MSE)**
#
# Ex: the SGD continues to minimize by updating the weights

# %% [markdown]
# #**Learning rate**: 0.01~0.0001

# %% [markdown]
# # Datasets
#
# **Training sets**: Labeled.   let the model learn (weights being adjusted in the training sets, not in the validation sets)
#
# **Validation sets**: Labeled.  Help adjusting hyperparameters (simultaneously validated with training sets), make sure the model doesnt over/underfitting
#
# if Training sets ✔️, Validation sets ✖️, ➡️ overfitting problem
#
# **Testing sets**: Unlabeled

# %%
scaled_trained_samples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de620b574e84> in <module>()
# ----> 1 scaled_trained_samples
#
# NameError: name 'scaled_trained_samples' is not defined

# %% [markdown]
# Data format: numpy arrays or list of numpy arrays

# %%
train_labels

# %% [markdown]
# label of the numpy array. Ex: array([1,0,1,...,1,0,0])

# %%
model.fit(scaled_trained_samples,train_labels,validation_split=0.20, batch_size=10,
          epochs=20, shuffle=True, verbose=2)

# %% [markdown]
# No need to create a validation set seperately, and it will be achieved by the 'validation_split'. 'validation_split=0.20'= extract 20% of the training sets for validation.

# %% [markdown]
# Or, the validation sets can be created explicitly which are separate from the training sets. 👇

# %%
valid_set=[(sample,label),(sample,label),...,(sample,label)]

# %%
model.fit(scaled_train_samples, train_labels, validation_data=valid_set,batch_size=10,
          epochs=20,shuffle=True, verbose=2)``

# %% [markdown]
# #**Predict**

# %%
predictions=model.predict(scaled_test_samples, batch_size=10, verbose=0)

# %%
for i in predictions:
    print(i)
